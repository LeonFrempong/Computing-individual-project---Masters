# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/7151CEM Computing individual project/MentalHealth_Results.csv')

# %%
df['1. What age group do you belong to?'].value_counts(normalize=True).plot(kind="bar", figsize=(15,7))
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df['2. Do you have a job?'].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#008000")
df['2. Do you have a job?'].value_counts(normalize=True)
plt.show()

# %%
df['3.1. Select'].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#ff0000")
plt.show()

# %%
df['4. How frequently do you feel pressured at work in a normal week?'].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#a4a4f6")
plt.show()

# %%
#5. When you're at work, how would you rank your overall happiness? (scale 1-10)
df["5.1. Select"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#767600")
plt.show()

# %%
df["6. Do you believe your job has a negative impact on your mental health?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#ede17b")
plt.show()

# %%
df["7. Would you consider yourself overweight?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#b76c80")
plt.show()

# %%
df["7.a. If yes, how does this effect you?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#b78880")
plt.show()

# %%
df["8. Do you know someone in your family or a friend who has struggled with obesity?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#b7ecf7")
plt.show()

# %%
df["8.a. If yes, how does this affect them?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#2b1f80")
plt.show()

# %%
df["9. Do you believe obesity has an impact on mental health?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#ffdb08")
plt.show()

# %%
df["10. On average, how would you describe your mental health?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#e98908")
plt.show()

# %%
df["11. During the past two weeks how often have you felt sad or depressed?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#6e8908")
plt.show()

# %%
df["12. During the past two weeks, how often has your mental health interfered with your personal relationships?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#d69dff")
plt.show()

# %%
df["13. During the past two weeks how often has your mental health interfered with your ability to get work done or accomplish tasks?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#d65e8e")
plt.show()

# %%
df["14. How many hours per week of physical activity do you take part in?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()

# %%
df["15. What type of physical activities do you currently take part in?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()

# %%
df["15. What type of physical activities do you currently take part in?"].value_counts(normalize=True)
# Out:
# Walking,Domestic-related e.g. cleaning the house, shopping etc.             0.185185
# Walking,Other                                                               0.111111
# Other                                                                       0.111111
# Domestic-related e.g. cleaning the house, shopping etc.                     0.074074
# Walking,Jogging,Domestic-related e.g. cleaning the house, shopping etc.     0.074074
# Walking                                                                     0.074074
# Walking,Dance                                                               0.037037
# Jogging,Other                                                               0.037037
# Walking,Football,Other                                                      0.037037
# Walking,Swimming,Domestic-related e.g. cleaning the house, shopping etc.    0.037037
# Walking,Football                                                            0.037037
# ...

# %%
df["16. If the following statement one that you feel applies to you: “I would like to take part in more sport and physical activity and believe that this would improve my general state of mental health”"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()
