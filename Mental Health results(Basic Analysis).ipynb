# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('MentalHealth_Results.csv')

# %%
df['1. What age group do you belong to?'].value_counts(normalize=True).plot(kind="bar", figsize=(15,7))
plt.show()

# %%
df['2. Do you have a job?'].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()

# %%
df['3.1. Select'].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()

# %%
df['4. How frequently do you feel pressured at work in a normal week?'].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()

# %%
#5. When you're at work, how would you rank your overall happiness? (scale 1-10)
df["5.1. Select"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()

# %%
df["6. Do you believe your job has a negative impact on your mental health?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()

# %%
df["7. Would you consider yourself overweight?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()

# %%
df["7.a. If yes, how does this effect you?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()

# %%
df["8. Do you know someone in your family or a friend who has struggled with obesity?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()

# %%
df["8.a. If yes, how does this affect them?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()

# %%
df["9. Do you believe obesity has an impact on mental health?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()

# %%
df["10. On average, how would you describe your mental health?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()

# %%
df["11. During the past two weeks how often have you felt sad or depressed?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()

# %%
df["12. During the past two weeks, how often has your mental health interfered with your personal relationships?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()

# %%
df["13. During the past two weeks how often has your mental health interfered with your ability to get work done or accomplish tasks?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()

# %%
df["14. How many hours per week of physical activity do you take part in?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()

# %%
df["15. What type of physical activities do you currently take part in?"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()

# %%
df["16. If the following statement one that you feel applies to you: “I would like to take part in more sport and physical activity and believe that this would improve my general state of mental health”"].value_counts(normalize=True).plot(kind="bar", figsize=(15,7), color="#663300")
plt.show()
